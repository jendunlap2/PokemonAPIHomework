# %% [markdown]
# # Python Requests

# %% [markdown]
# ## Tasks Today:
#
#
# 1) <b>Requests package</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) pip install <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) requests.get <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) Response object <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) .content and .text <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) JSON <br>
# 2) <b>Python Wrapper</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) API key and base url<br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Creating a class for our requests<br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) Private method for getting the response data <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) Public method for displaying the data <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) In-Class Exercise #1 - Add a method for getting the high and lows for the next 3 days <br>
# 3) <b>Exercises</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Exercise #1 - Pokemon Wrapper  <br>

# %% [markdown]
# ### Requests Package
# <a href='https://docs.python-requests.org/en/latest/'>Docs</a>

# %% [markdown]
# #### Install and import package

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\jendu\anaconda3\lib\site-packages (2.26.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jendu\anaconda3\lib\site-packages (from requests) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jendu\anaconda3\lib\site-packages (from requests) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jendu\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jendu\anaconda3\lib\site-packages (from requests) (3.2)

# %%
import requests
print(requests)
# Out:
# <module 'requests' from 'C:\\Users\\jendu\\anaconda3\\lib\\site-packages\\requests\\__init__.py'>

# %% [markdown]
# #### requests get method

# %%
res = requests.get('https://www.codingtemple.com')
print(res)
res
# Out:
# <Response [200]>
# <Response [200]>

# %% [markdown]
# #### Response object

# %%
print(type(res))
# Out:
# <class 'requests.models.Response'>

# %%
status_code
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11700/3624138812.py in <module>
# ----> 1 status_code
#
# NameError: name 'status_code' is not defined

# %% [markdown]
# #### .content

# %% [markdown]
# #### .text

# %% [markdown]
# #### JSON Response

# %%
poke_res = requests.get('http://www.pokeapi.co/api/v2/pokemon/pikachu')

# %%
poke_res.content

# %%
poke_res.text

# %%
print(poke_res.json)

# %% [markdown]
# ### Python Wrappers

# %%
weather_res = requests.get('https://api.weatherapi.com/v1/current.json?key=f10075802833438fba4193244212212&q=Dallas&aqi=no')

# %%
response_body = weather_res.json()
response_body

# %%
city_location = response_body['location']['name'] + ', ' + response_body['location']['region']
current_temp = response_body['current']['temp_f']
current_condition = response_body['current']['condition']['text']
print(city_location)
print(current_temp)
print(current_condition)

# %%
class WeatherAPI:
    
    def __init__(self, api_key):
        self.api_key = api_key
        self.base_url = 'https://api.weatherapi.com/v1'
        
    def _get(self, q='', api_method = '/current.json'):
        request_url = f"{self.base_url}{api_method}?key={self.api_key}&q={q}"
        res = requests.get(request_url)
        if res.ok:
            return res.json()
        else:
            print("There was an error.")
            
    def get_current_weather(self, city):
        data = self._get(city)
        display_name = data['location']['name'] + ', ' + data['location']['region']
        current_temp = data['current']['temp_f']
        current_condition = data['current']['condition']['text']
        feels_like = data['current']['feelslike_f']
        print(f"It is currently {current_condition} and {current_temp} in {display_name}. It feels like {feels_like}.")

        
weather = WeatherAPI('f10075802833438fba4193244212212')
weather._get('Dallas')
weather.get_current_weather('Fort Worth')

# %%
weather.get_current_weather('Chicago')

# %%
def run():
    weather_checker = WeatherAPI('f10075802833438fba4193244212212')
    while True:
        ask = input("For which city would you like to see the weather? ")
        if ask.lower() == 'quit':
            break
        weather_checker.get_current_weather(ask)
        
run()

# %% [markdown]
# #### In-class Exercise

# %% [markdown]
# Add a method for getting the forecast weather for a city. It should default to 3 days in the future. It should display the high, low and condition with the date.

# %%
class WeatherAPI:
    
    def __init__(self, api_key):
        self.api_key = api_key
        self.base_url = 'https://api.weatherapi.com/v1'
        
    def _get(self, q='', api_method = '/current.json', days=''):
        request_url = f"{self.base_url}{api_method}?key={self.api_key}&q={q}"
        res = requests.get(request_url)
        if res.ok:
            return res.json()
        else:
            print("There was an error.")
            
    def get_current_weather(self, city):
        data = self._get(city)
        display_name = data['location']['name'] + ', ' + data['location']['region']
        current_temp = data['current']['temp_f']
        current_condition = data['current']['condition']['text']
        feels_like = data['current']['feelslike_f']
        print(f"It is currently {current_condition} and {current_temp} in {display_name}. It feels like {feels_like}.")
        
    def get_forecast_weather(self, city, days=3):
        api_method = '/forecast.json'
        max_temp = data['forecast]'['forecastday']['maxtemp_f']
        min_temp = data['forecast']['forecastday']['mintemp_f']
        forecast_condition = data['forecast']['forecast_day'][2]['condition']['text']
        forecast_feels_like = data['forecast']['feelslike_f']
        print(f"It will be {forecast_condition} with a high of {max_temp} and a low of {min_temp}. It will feel like {forecast_feels_like}.")

#     def get_date(self):

# %%
get_forecast_weather('Dallas')

# %%
def run():
    weather_checker = WeatherAPI('f10075802833438fba4193244212212')
    while True:
        ask = input("For which city would you like to see the weather forecast? ")
        if ask.lower() == 'quit':
            break
        weather_checker.get_current_weather(ask)
        
run()

# %% [markdown]
# # Exercise

# %% [markdown]
# #### Pokemon API Wrapper

# %% [markdown]
# Create a python wrapper for the Pokemon API. It should take in a pokemon name and display the pokemon with its height and weight

# %%
class PokemonAPI():
    def __init__(self):
        self.base_url = 'https://pokeapi.co/api/v2/pokemon/'
       
    def _get(self, name):
        request_url = self.base_url + name
        poke_request = requests.get(request_url)
        
        if poke_request.ok:
            return poke_request.json()
        else:
            print(poke_request.status_code)
            print("Error")
        
    def get_height_weight(self, name):
        data = self._get(name)
        print(name)
        poke_height = data['height']
        poke_weight = data['weight']
        print(f'{name} is {self.poke_height} feet tall and weighs {self.poke_weight} pounds.')

# %%
PokemonAPI().get_height_weight('Pikachu')
PokemonAPI().get_height_weight('Gyrados')
# Out:
# 404
# Error
# Pikachu
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11700/3916318754.py in <module>
# ----> 1 PokemonAPI().get_height_weight('Pikachu')
#       2 PokemonAPI().get_height_weight('Gyrados')
#
# ~\AppData\Local\Temp/ipykernel_11700/1503712759.py in get_height_weight(self, name)
#      16         data = self._get(name)
#      17         print(name)
# ---> 18         poke_height = data['height']
#      19         poke_weight = data['weight']
#      20         print(f'{name} is {self.poke_height} feet tall and weighs {self.poke_weight} pounds.')
#
# TypeError: 'NoneType' object is not subscriptable
